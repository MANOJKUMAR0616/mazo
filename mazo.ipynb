# %%
#importing the library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data
data = pd.read_csv(r'C:\Users\USER\Desktop\internship\Assignment-1 Dataset.csv')

# %%
#explore the data
data.head()
# Out:
#    Alert Id  Alert Source            Timestamp       Location Severity  \
# 0          1  motherboard  2019-07-12 10:12:53         Denver      low
# 1          2          CPU  2021-06-26 07:26:56             IN     high
# 2          3   hard drive  2020-11-05 20:55:57  San Francisco   medium
# 3          4          GPU  2020-10-25 18:17:54             TX      low
# 4          5       router  2020-04-13 06:25:03         Dallas     high
#
#                        Description Affected Component  Assigned To  \
# 0         Database connection lost             Network        Mike
# 1                      Server down              Server       Emily
# 2      Unauthorized access attempt            Software        John
# 3  Memory usage exceeded threshold            Database        Sara
# 4      Unauthorized access attempt         Application        John
#
#         Status  Priority         Resolution Notes Escalation Level  \
# 0     resolved       Low  Investigating the issue          Level 4
# 1  in progress      High       Working on the fix          Level 4
# 2         open    Medium  Investigating the issue          Level 2
# 3     resolved      High             Fix deployed          Level 1
# 4     resolved  Critical       Working on the fix          Level 1
#
#                    Notifications         Labels
# 0     Email sent to stakeholders       critical
# 1     Email sent to stakeholders      important
# 2  Letter mailed to stakeholders  high priority
# 3       SMS sent to stakeholders  high priority
# 4       SMS sent to stakeholders   low priority

# %%
data.shape
# Out:
# (1000, 14)

# %%
len(data)
# Out:
# 1000

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Alert Id  Alert Source            Timestamp       Location Severity  \
# 0            1  motherboard  2019-07-12 10:12:53         Denver      low
# 1            2          CPU  2021-06-26 07:26:56             IN     high
# 2            3   hard drive  2020-11-05 20:55:57  San Francisco   medium
# 3            4          GPU  2020-10-25 18:17:54             TX      low
# 4            5       router  2020-04-13 06:25:03         Dallas     high
# ..         ...          ...                  ...            ...      ...
# 995        996         case  2022-06-30 10:25:41   Jacksonville     high
# 996        997          CPU  2021-02-09 20:25:32             NY   medium
# 997        998          RAM  2020-08-11 23:20:19             AZ   medium
# 998        999          RAM  2021-07-04 22:33:50             CA      low
# 999       1000        modem  2019-11-16 14:46:21             NC   medium
#
#                          Description Affected Component  Assigned To  \
# 0           Database connection lost             Network        Mike
# 1                        Server down              Server       Emily
# 2        Unauthorized access attempt            Software        John
# 3    Memory usage exceeded threshold            Database        Sara
# 4        Unauthorized access attempt         Application        John
# ..                               ...                 ...         ...
# 995  Memory usage exceeded threshold         Application        Mike
# 996          High CPU usage detected    Operating System        Sara
# 997      Unauthorized access attempt    Operating System        John
# 998          High CPU usage detected              Server        John
# 999         Database connection lost            Software       Alice
#
#           Status  Priority           Resolution Notes Escalation Level  \
# 0       resolved       Low    Investigating the issue          Level 4
# 1    in progress      High         Working on the fix          Level 4
# 2           open    Medium    Investigating the issue          Level 2
# 3       resolved      High               Fix deployed          Level 1
# 4       resolved  Critical         Working on the fix          Level 1
# ..           ...       ...                        ...              ...
# 995  in progress      High    Investigating the issue          Level 1
# 996         open    Medium  Identified the root cause          Level 2
# 997  in progress    Medium  Identified the root cause          Level 4
# 998  in progress       Low         Working on the fix          Level 1
# 999  in progress       Low         Working on the fix          Level 1
#
#                        Notifications         Labels
# 0         Email sent to stakeholders       critical
# 1         Email sent to stakeholders      important
# 2      Letter mailed to stakeholders  high priority
# 3           SMS sent to stakeholders  high priority
# 4           SMS sent to stakeholders   low priority
# ..                               ...            ...
# 995         SMS sent to stakeholders       critical
# 996  Phone call made to stakeholders   low priority
# 997         SMS sent to stakeholders      important
# 998         SMS sent to stakeholders       critical
# 999         SMS sent to stakeholders  high priority
#
# [1000 rows x 14 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of      Alert Id  Alert Source            Timestamp       Location Severity  \
# 0            1  motherboard  2019-07-12 10:12:53         Denver      low
# 1            2          CPU  2021-06-26 07:26:56             IN     high
# 2            3   hard drive  2020-11-05 20:55:57  San Francisco   medium
# 3            4          GPU  2020-10-25 18:17:54             TX      low
# 4            5       router  2020-04-13 06:25:03         Dallas     high
# ..         ...          ...                  ...            ...      ...
# 995        996         case  2022-06-30 10:25:41   Jacksonville     high
# 996        997          CPU  2021-02-09 20:25:32             NY   medium
# 997        998          RAM  2020-08-11 23:20:19             AZ   medium
# 998        999          RAM  2021-07-04 22:33:50             CA      low
# 999       1000        modem  2019-11-16 14:46:21             NC   medium
#
#                          Description Affected Component  Assigned To  \
# 0           Database connection lost             Network        Mike
# 1                        Server down              Server       Emily
# 2        Unauthorized access attempt            Software        John
# 3    Memory usage exceeded threshold            Database        Sara
# 4        Unauthorized access attempt         Application        John
# ..                               ...                 ...         ...
# 995  Memory usage exceeded threshold         Application        Mike
# 996          High CPU usage detected    Operating System        Sara
# 997      Unauthorized access attempt    Operating System        John
# 998          High CPU usage detected              Server        John
# 999         Database connection lost            Software       Alice
#
#           Status  Priority           Resolution Notes Escalation Level  \
# 0       resolved       Low    Investigating the issue          Level 4
# 1    in progress      High         Working on the fix          Level 4
# 2           open    Medium    Investigating the issue          Level 2
# 3       resolved      High               Fix deployed          Level 1
# 4       resolved  Critical         Working on the fix          Level 1
# ..           ...       ...                        ...              ...
# 995  in progress      High    Investigating the issue          Level 1
# 996         open    Medium  Identified the root cause          Level 2
# 997  in progress    Medium  Identified the root cause          Level 4
# 998  in progress       Low         Working on the fix          Level 1
# 999  in progress       Low         Working on the fix          Level 1
#
#                        Notifications         Labels
# 0         Email sent to stakeholders       critical
# 1         Email sent to stakeholders      important
# 2      Letter mailed to stakeholders  high priority
# 3           SMS sent to stakeholders  high priority
# 4           SMS sent to stakeholders   low priority
# ..                               ...            ...
# 995         SMS sent to stakeholders       critical
# 996  Phone call made to stakeholders   low priority
# 997         SMS sent to stakeholders      important
# 998         SMS sent to stakeholders       critical
# 999         SMS sent to stakeholders  high priority
#
# [1000 rows x 14 columns]>

# %%
data.nunique()
# Out:
# Alert Id               1000
# Alert Source             12
# Timestamp              1000
# Location                 33
# Severity                  3
# Description               5
# Affected Component        9
# Assigned To              10
# Status                    3
# Priority                  4
# Resolution Notes          5
# Escalation Level          5
# Notifications             4
# Labels                    6
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Alert Id               0
# Alert Source           0
# Timestamp              0
# Location               0
# Severity               0
# Description            0
# Affected Component     0
# Assigned To            0
# Status                 0
# Priority               0
# Resolution Notes       0
# Escalation Level       0
# Notifications          0
# Labels                 0
# dtype: int64

# %%
data['Severity'].value_counts()
# Out:
# high      347
# low       330
# medium    323
# Name: Severity, dtype: int64

# %%
# Plotting a histogram of the Severity column
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='Severity')
plt.title('Severity Distribution')
plt.xlabel('Severity')
plt.ylabel('Count')
plt.show()

# %%
# Plotting a bar chart of the top 10 most common Alert Sources
top_alert_sources = data['Alert Source'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_alert_sources.index, y=top_alert_sources.values)
plt.title('Top 10 Alert Sources')
plt.xlabel('Alert Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
categorical_cols = ['Location', 'Severity', 'Assigned To', 'Status', 'Priority']
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    data[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.xlabel('Categories')
    plt.ylabel('Count')
    plt.show()
